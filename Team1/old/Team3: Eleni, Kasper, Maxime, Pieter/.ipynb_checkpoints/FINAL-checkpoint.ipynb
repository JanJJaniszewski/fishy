# %% [markdown]
# # Importing

# %%
# Plot ad hoc CIFAR10 instances
from keras.datasets import cifar10
from matplotlib import pyplot
from scipy.misc import toimage
# Simple CNN model for CIFAR-10
import numpy
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import Flatten
from keras.constraints import maxnorm
from keras.optimizers import SGD
from keras.layers.convolutional import Convolution2D
from keras.layers.convolutional import MaxPooling2D
from keras.utils import np_utils
from keras import backend as K
K.set_image_dim_ordering('th')
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline  
from PIL import Image
import glob
import numpy as np
import pandas as pd
from IPython.display import Image
from IPython.display import Image
from IPython.display import Image
from IPython.core.display import HTML

# %% [markdown]
# # Read the data
#
# Read the file names from `../Data/Kaggle/train/*`.

# %%
# the folder path to the folder with all the fishies in there
folders_path = '../Team 3/Zoomed train/*'

# creating a dataframe with the columns below
image_dict = {}

# going through all folders and saving file names in dataframe so that order is always correct
for foldername in glob.glob(folders_path):
    for image_name in glob.glob(foldername + '/*.jpg'):
        # getting image name and fish type and putting it in a dictionary
        fish_type = foldername[-3:]
        image_dict[image_name] = fish_type

image_df = pd.DataFrame(image_dict.items(), columns = ['image_name', 'fish_type']).sample(frac=1) # random sampling
dummy_df = pd.get_dummies(image_df, columns=['fish_type']) # dummify data
print(dummy_df)
# Out:
#                                       image_name  fish_type_ALB  \
# 1509    ../Team 3/Zoomed train/YFT/img_06054.jpg              0
# 3037    ../Team 3/Zoomed train/YFT/img_02976.jpg              0
# 319     ../Team 3/Zoomed train/YFT/img_02165.jpg              0
# 3332    ../Team 3/Zoomed train/ALB/img_05681.jpg              1
# 3720  ../Team 3/Zoomed train/OTHER/img_05753.jpg              0
# 7       ../Team 3/Zoomed train/BET/img_04931.jpg              0
# 1226    ../Team 3/Zoomed train/NoF/img_00419.jpg              0
# 992     ../Team 3/Zoomed train/ALB/img_03090.jpg              1
# 3614    ../Team 3/Zoomed train/ALB/img_06460.jpg              1
# 2882    ../Team 3/Zoomed train/ALB/img_07396.jpg              1
# 3071    ../Team 3/Zoomed train/ALB/img_01186.jpg              1
# 16      ../Team 3/Zoomed train/ALB/img_02025.jpg              1
# 1195    ../Team 3/Zoomed train/DOL/img_02432.jpg              0
# 97      ../Team 3/Zoomed train/BET/img_02647.jpg              0
# 1920    ../Team 3/Zoomed train/ALB/img_00270.jpg              1
# 1641  ../Team 3/Zoomed train/OTHER/img_06005.jpg              0
# 1011    ../Team 3/Zoomed train/ALB/img_04633.jpg              1
# 1996    ../Team 3/Zoomed train/ALB/img_07862.jpg              1
# 3626    ../Team 3/Zoomed train/ALB/img_03569.jpg              1
# 2240    ../Team 3/Zoomed train/BET/img_06384.jpg              0
# 1458  ../Team 3/Zoomed train/OTHER/img_03070.jpg              0
# 2336    ../Team 3/Zoomed train/LAG/img_02186.jpg              0
# 2722    ../Team 3/Zoomed train/ALB/img_06185.jpg              1
# 2478    ../Team 3/Zoomed train/YFT/img_02055.jpg              0
# 1119    ../Team 3/Zoomed train/ALB/img_06126.jpg              1
# 1294    ../Team 3/Zoomed train/NoF/img_02997.jpg              0
# 446     ../Team 3/Zoomed train/ALB/img_00690.jpg              1
# 2998    ../Team 3/Zoomed train/ALB/img_07193.jpg              1
# 446               0              0              0              0
# 2998              0              0              0              0
# 1046              0              0              0              0
# 879               0              0              0              0
# ...             ...            ...            ...            ...
# 1727              0              0              0              0
# 3107              1              0              0              0
# 3751              0              0              0              0
# 59                0              0              0              0
# 2273              0              0              1              0
# 2256              0              0              0              1
# 418               0              0              0              0
# 2927              0              0              0              1
# 3310              0              1              0              0
# 1551              0              0              0              0
# 628               0              0              0              0
# 1109              0              0              0              0
# 289               0              0              0              0
# 1287              0              0              0              0
# 1927              0              0              0              0
# 806               0              0              0              1
# 244               0              0              0              0
# 1629              0              0              0              0
# 3389              0              0              0              0
# 773               0              0              0              0
# 3036              0              0              0              0
# 2276              0              0              0              0
# 86                0              0              0              1
# 94                0              0              0              1
# 329               0              0              0              0
# 2610              0              0              0              0
# 2800              0              0              0              0
# 1600              0              0              0              0
# 1033              0              0              0              0
# 3476              0              0              0              0
#
#       fish_type_LAG  fish_type_NoF  fish_type_YFT
# 1509              0              0              1
# 3037              0              0              1
# 319               0              0              1
# 3332              0              0              0
# 3720              0              0              0
# 7                 0              0              0
# 1226              0              1              0
# 992               0              0              0
# 3614              0              0              0
# 2882              0              0              0
# 3071              0              0              0
# 16                0              0              0
# 1195              0              0              0
# 97                0              0              0
# 1920              0              0              0
# 1641              0              0              0
# 1011              0              0              0
# 1996              0              0              0
# 3626              0              0              0
# 2240              0              0              0
# 1458              0              0              0
# 2336              1              0              0
# 2722              0              0              0
# 2478              0              0              1
# 1119              0              0              0
# 1294              0              1              0
# 446               0              0              0
# 2998              0              0              0
# 1046              0              0              1
# 879               0              0              0
# ...             ...            ...            ...
# 1727              0              0              0
# 3107              0              0              0
# 3751              0              0              0
# 59                0              0              0
# 2273              0              0              0
# 2256              0              0              0
# 418               0              0              0
# 2927              0              0              0
# 3310              0              0              0
# 1551              0              0              0
# 628               0              0              1
# 1109              0              1              0
# 289               0              0              0
# 1287              0              0              1
# 1927              0              0              0
# 806               0              0              0
# 244               0              1              0
# 1629              0              0              0
# 3389              0              0              0
# 773               0              0              0
# 3036              0              0              0
# 2276              0              0              1
# 86                0              0              0
# 94                0              0              0
# 329               0              0              0
# 2610              1              0              0
# 2800              0              1              0
# 1600              0              1              0
# 1033              0              0              1
# 3476              0              0              0
#
# [3777 rows x 9 columns]

# %%
test_path = '../Team 3/Zoomed test/'

# creating a dataframe with the columns below
image_dict = {}

# going through all folders and saving file names in dataframe so that order is always correct

for image_name in glob.glob(test_path + '/*.jpg'):
    # getting image name and fish type and putting it in a dictionary
    fish_type = foldername[-3:]
    image_dict[image_name] = fish_type
#print(image_dict)
image_df = pd.DataFrame(image_dict.items(), columns = ['image_name', 'fish_type']) # random sampling
test_df = pd.get_dummies(image_df, columns=['fish_type']) # dummify data
print(test_df)
# Out:
#                               image_name  fish_type_NoF
# 0    ../Team 3/Zoomed test/img_02641.jpg              1
# 1    ../Team 3/Zoomed test/img_01633.jpg              1
# 993  ../Team 3/Zoomed test/img_06946.jpg              1
# 994  ../Team 3/Zoomed test/img_07501.jpg              1
# 995  ../Team 3/Zoomed test/img_06147.jpg              1
# 996  ../Team 3/Zoomed test/img_03283.jpg              1
# 997  ../Team 3/Zoomed test/img_03370.jpg              1
# 998  ../Team 3/Zoomed test/img_04503.jpg              1
# 999  ../Team 3/Zoomed test/img_00161.jpg              1
#
# [1000 rows x 2 columns]

# %%
# Count of the image types
#image_df.groupby('fish_type').count().sort_values('image_name')

# %% [markdown]
# # Preprocess

# %% [markdown]
# # Manual preprocessing
# * Read the image from file
# * Resize it to (224, 224)
# * Set type to np.float (such that it can be reschaled to 0-1)
# * Rescale to 0-1
# * Subtract mean

# %%
## For training

images = []
## For training

images = []

for filename in dummy_df.image_name:
    img = cv2.imread(filename) # Read file    
    img = cv2.resize(img, (224, 224)) # Resize image to 224 x 224 pixels (dont feel obliged to use this)
    img = img.astype(np.float32) # Change to 32 bit floats (good for neural networks, other floats not as much making sense)

    # "Normalize" images
    for rgb_value in [0,1,2]:
        img[:, :, rgb_value] = img[:, :, rgb_value] / 255.0 # 255 is the RGB maximum
        img[:, :, rgb_value] -= numpy.mean(img[:, :, rgb_value])

    img = img.transpose((2,0,1))
    images.append(img)

# X and y value and labels
x = np.asarray(images)
y = dummy_df.iloc[:,1:9].as_matrix()

# For inspection: table, just to be sure that everything goes well
labels = dummy_df.image_name.apply(lambda path: path[-13:])
dummy_df['image_bytes'] = images

split_no = int(len(x) * 0.9)

x_train = x[:split_no]
y_train = y[:split_no]
labels_train = labels[:split_no]

x_test = x[split_no:]
y_test = y[split_no:]
labels_test = labels[split_no:]
print(labels_test)
for filename in dummy_df.image_name:
    img = cv2.imread(filename) # Read file    
    img = cv2.resize(img, (224, 224)) # Resize image to 224 x 224 pixels (dont feel obliged to use this)
    img = img.astype(np.float32) # Change to 32 bit floats (good for neural networks, other floats not as much making sense)

    # "Normalize" images
    for rgb_value in [0,1,2]:
        img[:, :, rgb_value] = img[:, :, rgb_value] / 255.0 # 255 is the RGB maximum
        img[:, :, rgb_value] -= numpy.mean(img[:, :, rgb_value])

    img = img.transpose((2,0,1))
    images.append(img)

# X and y value and labels
x = np.asarray(images)
y = dummy_df.iloc[:,1:9].as_matrix()

# For inspection: table, just to be sure that everything goes well
labels = dummy_df.image_name.apply(lambda path: path[-13:])
dummy_df['image_bytes'] = images

split_no = int(len(x) * 0.9)

x_train = x[:split_no]
y_train = y[:split_no]
labels_train = labels[:split_no]

x_test = x[split_no:]
y_test = y[split_no:]
labels_test = labels[split_no:]
print(labels_test)
# Out:
# 2861    img_02987.jpg
# 264     img_03147.jpg
# 915     img_05014.jpg
# 1439    img_06686.jpg
# 744     img_03315.jpg
# 671     img_04231.jpg
# 2570    img_05689.jpg
# 2580    img_02554.jpg
# 2275    img_06579.jpg
# 2890    img_07730.jpg
# 3328    img_05485.jpg
# 3154    img_07074.jpg
# 2064    img_03101.jpg
# 3358    img_07892.jpg
# 3201    img_02179.jpg
# 604     img_07271.jpg
# 1973    img_05553.jpg
# 2095    img_07569.jpg
# 2143    img_06588.jpg
# 49      img_02034.jpg
# 721     img_04062.jpg
# 2898    img_03369.jpg
# 2869    img_07854.jpg
# 1849    img_07724.jpg
# 1555    img_03530.jpg
# 479     img_01686.jpg
# 2735    img_01403.jpg
# 2471    img_00238.jpg
# 3647    img_03686.jpg
# 1533    img_00961.jpg
#             ...
# 1727    img_00840.jpg
# 3107    img_06118.jpg
# 3751    img_07442.jpg
# 59      img_04728.jpg
# 2273    img_03843.jpg
# 2256    img_06382.jpg
# 418     img_02925.jpg
# 2927    img_05954.jpg
# 3310    img_03347.jpg
# 1551    img_01603.jpg
# 628     img_04317.jpg
# 1109    img_04151.jpg
# 289     img_00713.jpg
# 1287    img_01808.jpg
# 1927    img_04153.jpg
# 806     img_07415.jpg
# 244     img_03757.jpg
# 1629    img_01980.jpg
# 3389    img_06607.jpg
# 773     img_02484.jpg
# 3036    img_06979.jpg
# 2276    img_01721.jpg
# 86      img_00263.jpg
# 94      img_03365.jpg
# 329     img_01082.jpg
# 2610    img_00657.jpg
# 2800    img_07660.jpg
# 1600    img_03221.jpg
# 1033    img_01700.jpg
# 3476    img_01262.jpg
# Name: image_name, dtype: object

# %%
## For test set

test_images = []

for filename in test_df.image_name:
    img = cv2.imread(filename) # Read file    
    img = cv2.resize(img, (224, 224)) # Resize image to 224 x 224 pixels (dont feel obliged to use this)
    img = img.astype(np.float32) # Change to 32 bit floats (good for neural networks, other floats not as much making sense)

    # "Normalize" images
    for rgb_value in [0,1,2]:
        img[:, :, rgb_value] = img[:, :, rgb_value] / 255.0 # 255 is the RGB maximum
        img[:, :, rgb_value] -= numpy.mean(img[:, :, rgb_value])

    img = img.transpose((2,0,1))
    test_images.append(img)

# X and y value and labels
xt = np.asarray(images)
y = test_df.iloc[:,1:9].as_matrix()

# For inspection: table, just to be sure that everything goes well
labels = test_df.image_name.apply(lambda path: path[-13:])
test_df['image_bytes'] = test_images

# %%
print(test_df.head())
# Out:
#                             image_name  fish_type_NoF  \
# 0  ../Team 3/Zoomed test/img_02641.jpg              1
# 1  ../Team 3/Zoomed test/img_01633.jpg              1
# 2  ../Team 3/Zoomed test/img_04002.jpg              1
# 3  ../Team 3/Zoomed test/img_04310.jpg              1
# 4  ../Team 3/Zoomed test/img_02954.jpg              1
#
#                                          image_bytes
# 0  [[[-0.0105736, -0.061554, -0.0576324, -0.01841...
# 1  [[[-0.0126095, -0.0479036, -0.102806, -0.03221...
# 2  [[[-0.148329, -0.148329, -0.144408, -0.144408,...
# 3  [[[0.0686939, 0.0647724, 0.0569292, 0.0530077,...
# 4  [[[-0.163526, -0.159605, -0.151761, -0.163526,...

# %%
print y.shape
# Out:
# (1000, 2)

# %% [markdown]
# ## Automated preprocessing: fish finder

# %%
# do stuff here

# %% [markdown]
# # Feature extraction

# %% [markdown]
# ## Definition

# %%
from keras.applications.vgg19 import VGG19
from keras.preprocessing import image
from keras.applications.vgg19 import preprocess_input
from keras.models import Model
import numpy as np

base_model = VGG19(weights='imagenet')
model = Model(input=base_model.input, output=base_model.get_layer('block4_pool').output)

def feature_generator(x, reshape=False):
    x = preprocess_input(x)
    pred = model.predict(x)
    if reshape:
        pred = pred.reshape(pred.shape[0],-1)
    return pred

# %% [markdown]
# ## Generation

# %%
# Disabled by default, takes ~50min
feat = feature_generator(xt)

# %% [markdown]
# ## Saving features

# %%
numpy.save('featurescropped.npy', feat)

# %% [markdown]
# ## Loading features

# %%
feat = numpy.load('features.npy')

# %%
print feat.shape
x_train_feat = feat[:split_no,:,:,:]

x_train_feat.shape

x_test_feat = feat[split_no:,:,:,:]
print(x_train_feat.shape)
print(x_test_feat.shape)
print(y_train.shape)
print(y_test.shape)
print(x_test_feat)
# Out:
# (3777, 512, 14, 14)
# (3399, 512, 14, 14)
# (378, 512, 14, 14)
# (3399, 8)
# (378, 8)
# [[[[  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   1.36936890e+02   2.33586990e+02]
#    [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       1.48079157e+01   1.62073547e+02   2.76081604e+02]
#    [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       2.13685060e+00   1.28994476e+02   2.23467331e+02]
#    ...,
#    [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       4.55958672e+01   1.59181259e+02   2.30200989e+02]
#    [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       4.80814667e+01   1.59722122e+02   3.27131897e+02]
#    [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   0.00000000e+00   1.97945953e+02]]
#
#   [[  1.64355316e+02   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   0.00000000e+00   0.00000000e+00]
#    [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   0.00000000e+00   0.00000000e+00]
#    [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   0.00000000e+00   0.00000000e+00]
#    ...,
#    [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   0.00000000e+00   0.00000000e+00]
#    [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   0.00000000e+00   0.00000000e+00]
#    [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   0.00000000e+00   0.00000000e+00]]
#
#   [[  6.94559708e+01   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   0.00000000e+00   0.00000000e+00]
#    [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   0.00000000e+00   0.00000000e+00]
#    [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   0.00000000e+00   0.00000000e+00]
#    ...,
#    [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   0.00000000e+00   0.00000000e+00]
#    [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   0.00000000e+00   0.00000000e+00]
#    [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   0.00000000e+00   0.00000000e+00]]
#
#   ...,
#   [[  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   0.00000000e+00   0.00000000e+00]
#    [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   0.00000000e+00   0.00000000e+00]
#    [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   0.00000000e+00   0.00000000e+00]
#    ...,
#    [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   0.00000000e+00   0.00000000e+00]
#    [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   0.00000000e+00   0.00000000e+00]
#    [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   0.00000000e+00   0.00000000e+00]]
#
#   [[  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   0.00000000e+00   0.00000000e+00]
#    [  0.00000000e+00   1.16446159e+02   6.68684311e+01 ...,
#       6.29965401e+01   0.00000000e+00   1.13523979e+02]
#    [  0.00000000e+00   7.88146667e+01   5.41141434e+01 ...,
#       4.61878700e+01   0.00000000e+00   7.78586044e+01]
#    ...,
#    [  0.00000000e+00   4.84997797e+00   0.00000000e+00 ...,
#       0.00000000e+00   0.00000000e+00   8.90906048e+00]
#    [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   2.46544037e+01   1.82004425e+02]
#    [  3.54951508e+02   1.30467041e+02   1.65246338e+02 ...,
#       1.70159210e+02   3.35940643e+02   3.96262848e+02]]
#
#   [[  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   0.00000000e+00   0.00000000e+00]
#    [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   0.00000000e+00   0.00000000e+00]
#    [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   0.00000000e+00   0.00000000e+00]
#    ...,
#    [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   0.00000000e+00   0.00000000e+00]
#    [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   0.00000000e+00   0.00000000e+00]
#    [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   0.00000000e+00   0.00000000e+00]]]
#
#
#  [[[  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   1.40335144e+02   2.36286728e+02]
#    [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       1.70967045e+01   1.65394577e+02   2.79740540e+02]
#    [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       3.02850437e+00   1.31141174e+02   2.26966217e+02]
#    ...,
#    [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       1.35906191e+01   1.44413391e+02   2.37131470e+02]
#    [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       3.85973434e+01   1.69719696e+02   3.39244812e+02]
#    [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   1.33215923e+01   2.19628616e+02]]
#
#   [[  1.67105972e+02   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   0.00000000e+00   0.00000000e+00]
#    [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   0.00000000e+00   0.00000000e+00]
#    [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   0.00000000e+00   0.00000000e+00]
#    ...,
#    [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   0.00000000e+00   0.00000000e+00]
#    [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   0.00000000e+00   0.00000000e+00]
#    [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   0.00000000e+00   0.00000000e+00]]
#
#   [[  7.00599289e+01   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   0.00000000e+00   0.00000000e+00]
#    [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   0.00000000e+00   0.00000000e+00]
#    [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   0.00000000e+00   0.00000000e+00]
#    ...,
#    [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   0.00000000e+00   0.00000000e+00]
#    [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   0.00000000e+00   0.00000000e+00]
#    [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   0.00000000e+00   0.00000000e+00]]
#
#   ...,
#   [[  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   0.00000000e+00   0.00000000e+00]
#    [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   0.00000000e+00   0.00000000e+00]
#    [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   0.00000000e+00   0.00000000e+00]
#    ...,
#    [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   0.00000000e+00   0.00000000e+00]
#    [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   0.00000000e+00   0.00000000e+00]
#    [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   0.00000000e+00   0.00000000e+00]]
#
#   [[  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   0.00000000e+00   0.00000000e+00]
#    [  0.00000000e+00   1.18137604e+02   7.09990768e+01 ...,
#       6.23940468e+01   0.00000000e+00   1.10901382e+02]
#    [  0.00000000e+00   7.90471115e+01   5.64768562e+01 ...,
#       4.74219742e+01   0.00000000e+00   7.71003494e+01]
#    ...,
#    [  0.00000000e+00   5.07015753e+00   0.00000000e+00 ...,
#       0.00000000e+00   0.00000000e+00   4.89218063e+01]
#    [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   0.00000000e+00   2.05127731e+02]
#    [  3.57096985e+02   1.32037796e+02   1.66112091e+02 ...,
#       1.73257446e+02   3.35866211e+02   4.08052551e+02]]
#
#   [[  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   0.00000000e+00   0.00000000e+00]
#    [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   0.00000000e+00   0.00000000e+00]
#    [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   0.00000000e+00   0.00000000e+00]
#    ...,
#    [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   0.00000000e+00   0.00000000e+00]
#    [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   0.00000000e+00   0.00000000e+00]
#    [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   0.00000000e+00   0.00000000e+00]]]
#
#
#  [[[  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   1.39974640e+02   2.35961197e+02]
#    [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       1.53918753e+01   1.64916214e+02   2.78399780e+02]
#    [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       3.71057272e+00   1.29138901e+02   2.23420380e+02]
#    ...,
#    [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       1.45200462e+01   1.42588821e+02   2.41773773e+02]
#    [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       3.73771439e+01   1.59869278e+02   3.39085022e+02]
#    [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   0.00000000e+00   2.10043732e+02]]
#
#   [[  1.68762054e+02   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   0.00000000e+00   0.00000000e+00]
#    [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   0.00000000e+00   0.00000000e+00]
#    [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   0.00000000e+00   0.00000000e+00]
#    ...,
#    [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   0.00000000e+00   0.00000000e+00]
#    [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   0.00000000e+00   0.00000000e+00]
#    [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   0.00000000e+00   0.00000000e+00]]
#
#   [[  6.70964355e+01   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   0.00000000e+00   0.00000000e+00]
#    [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   0.00000000e+00   0.00000000e+00]
#    [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   0.00000000e+00   0.00000000e+00]
#    ...,
#    [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   0.00000000e+00   0.00000000e+00]
#    [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   0.00000000e+00   0.00000000e+00]
#    [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   0.00000000e+00   0.00000000e+00]]
#
#

#    [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   0.00000000e+00   1.95149918e+02]
#    [  3.54110748e+02   1.30710129e+02   1.63906860e+02 ...,
#       1.72153900e+02   3.33492493e+02   4.12293884e+02]]
#
#   [[  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   0.00000000e+00   0.00000000e+00]
#    [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   0.00000000e+00   0.00000000e+00]
#    [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   0.00000000e+00   0.00000000e+00]
#    ...,
#    [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   0.00000000e+00   0.00000000e+00]
#    [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   0.00000000e+00   0.00000000e+00]
#    [  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,
#       0.00000000e+00   0.00000000e+00   0.00000000e+00]]]]

# %% [markdown]
# ## Top Model

# %%
# build a classifier model to put on top of the convolutional model
top_model = Sequential()
top_model.add(Flatten(input_shape=(512, 14, 14)))
top_model.add(Dense(256, activation='relu'))
top_model.add(Dropout(0.5))
top_model.add(Dense(8, activation='sigmoid'))
top_model.compile(optimizer='rmsprop',
                  loss='categorical_crossentropy',
                  metrics=['binary_crossentropy'])

# %%
print(x_train_feat.shape)
print(y_train.shape)
print(feat.shape)
print(y_test.shape)
# Out:
# (3399, 512, 14, 14)
# (3399, 8)
# (3777, 512, 14, 14)
# (378, 8)

# %%
top_model.fit(x_train_feat, y_train, validation_data=(x_test_feat, y_test))
# Final evaluation of the model
scores = top_model.evaluate(x_test_feat, y_test, verbose=0)
classes = top_model.predict_proba(x_test_feat, batch_size=32)

# get probability table
proba_df = pd.DataFrame(classes)
proba_df.columns = image_df.groupby('fish_type').count().index # workaround to get column names quickly and in right order

print(scores)
print(top_model.metrics_names)
print("Score: %.2f%%" % (scores[1]*10))
#with all images: 37%
print ' '
proba_df['image'] = labels
proba_df.to_csv('../Team 3/group3fantasticresults.csv')
# Out:
# Train on 3399 samples, validate on 378 samples
# Epoch 1/10
# 3399/3399 [==============================] - 21s - loss: 5.8367 - binary_crossentropy: 5.3187 - val_loss: 5.2310 - val_binary_crossentropy: 5.0882
# Epoch 2/10
# 3399/3399 [==============================] - 28s - loss: 5.5103 - binary_crossentropy: 5.6689 - val_loss: 5.2310 - val_binary_crossentropy: 5.0882
# Epoch 3/10
# 3399/3399 [==============================] - 23s - loss: nan - binary_crossentropy: nan - val_loss: nan - val_binary_crossentropy: nan
# Epoch 4/10
# 3399/3399 [==============================] - 30s - loss: nan - binary_crossentropy: nan - val_loss: nan - val_binary_crossentropy: nan
# Epoch 5/10
# 3399/3399 [==============================] - 29s - loss: nan - binary_crossentropy: nan - val_loss: nan - val_binary_crossentropy: nan
# Epoch 6/10
# 3399/3399 [==============================] - 29s - loss: nan - binary_crossentropy: nan - val_loss: nan - val_binary_crossentropy: nan
# Epoch 7/10
# 3399/3399 [==============================] - 29s - loss: nan - binary_crossentropy: nan - val_loss: nan - val_binary_crossentropy: nan
# Epoch 8/10
# 3399/3399 [==============================] - 29s - loss: nan - binary_crossentropy: nan - val_loss: nan - val_binary_crossentropy: nan
# Epoch 9/10
# 3399/3399 [==============================] - 30s - loss: nan - binary_crossentropy: nan - val_loss: nan - val_binary_crossentropy: nan
# Epoch 10/10
# 3399/3399 [==============================] - 30s - loss: nan - binary_crossentropy: nan - val_loss: nan - val_binary_crossentropy: nan
# 378/378 [==============================] - 0s
# ValueErrorTraceback (most recent call last)
# <ipython-input-117-236b55f488f5> in <module>()
#       6 # get probability table
#       7 proba_df = pd.DataFrame(classes)
# ----> 8 proba_df.columns = image_df.groupby('fish_type').count().index # workaround to get column names quickly and in right order
#       9
#      10 print(scores)
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/generic.pyc in __setattr__(self, name, value)
#    2755         try:
#    2756             object.__getattribute__(self, name)
# -> 2757             return object.__setattr__(self, name, value)
#    2758         except AttributeError:
#    2759             pass
#
# pandas/src/properties.pyx in pandas.lib.AxisProperty.__set__ (pandas/lib.c:46249)()
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/generic.pyc in _set_axis(self, axis, labels)
#     446
#     447     def _set_axis(self, axis, labels):
# --> 448         self._data.set_axis(axis, labels)
#     449         self._clear_item_cache()
#     450
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/internals.pyc in set_axis(self, axis, new_labels)
#    2800             raise ValueError('Length mismatch: Expected axis has %d elements, '
#    2801                              'new values have %d elements' %
# -> 2802                              (old_len, new_len))
#    2803
#    2804         self.axes[axis] = new_labels
#
# ValueError: Length mismatch: Expected axis has 8 elements, new values have 1 elements

# %%
model.predict()
